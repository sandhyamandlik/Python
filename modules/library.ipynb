# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
##random

import random
print(random.randint(1,10))
print(random.choice(['apple','cherry','banana']))
# Out:
# 6
# cherry

# %%
## file and directory access

import os
print(os.getcwd())
# Out:
# c:\Users\sandh\OneDrive\Desktop\Data Analytics Bootcamp\python\standard library

# %%
os.mkdir('test_dir')

# %%
## high level operation on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization

import json
data={'name':'sandhya','age':21}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "sandhya", "age": 21}
# <class 'str'>
# {'name': 'sandhya', 'age': 21}
# <class 'dict'>

# %%
## csv

import csv
with open('example.csv',mode='w',newline='') as file:
  writer=csv.writer(file)
  writer.writerow(['name','age'])
  writer.writerow(['krish',32])

with open('example.csv',mode='r') as file:
  reader=csv.reader(file)
  for row  in reader:
    print(row)
# Out:
# ['name', 'age']
# ['krish', '32']

# %%
## date time

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)

print(yesterday)
# Out:
# 2025-01-14 12:10:10.416598
# 2025-01-13 12:10:10.416598

# %%
## time

import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1736836904.1587274
# 1736836906.1622393

# %%
## regular expression
import re

pattern=r'\d+'
text='there are 456 apple'
match=re.search(pattern,text)
print(match.group())
# Out:
# 456
