# %%
a=100

# %%
##declaring and assigning variables

age=32
height=6.2
name="sandhya"
is_student=True

##printing the variables

print("age:",age)
print("height:",height)
print("name",name)
# Out:
# age: 32
# height: 6.2
# name sandhya

# %%
##naming conventions
##variables names should be descriptive
## they must always start with letter or an '_' and contain letter,numbers and underscores
## variables name are case sensitive

first_name="SAndhya"
last_name="mandlik"

# %%
#inavlid variable name
##2age=30
#first-name="sandhya"
#@name="sandhya"
# Out:
#   Cell In[5], line 3
#     first-name="sandhya"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
## understanding variable types
# python ids dyanamically typed,type of a variable is determined at runtime

age=25
height=6.1
name="sandhya"
is_student=True

print(type(name))
# Out:
# <class 'str'>

# %%
##typechecking and conversion

type(height)
# Out:
# float

# %%
age=32
print(type(age))

#type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 32
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="sandhya"
print(int(name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 name="sandhya"
# ----> 2 print(int(name))
#
# ValueError: invalid literal for int() with base 10: 'sandhya'

# %%
height=5.11
print(type(height))
# Out:
# <class 'float'>

# %%
float(int(height))
# Out:
# 5.0

# %%
#dynamic typing
var=10
print(var,type(var))

var="hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input
age=input("what is the age")
print(age, type(age))
# Out:
# 34 <class 'str'>

# %%
##simple calculator

num1=float(input("enter the first number:"))
num2=float(input("enter the second number:"))

sum=num1+num2
difference=num1-num2
product=num1*num2
quotient=num1/num2

print("sum:",sum)
print("difference:",difference)
print("product:",product)
print("quotient:",quotient)
# Out:
# sum: 7.0
# difference: -1.0
# product: 12.0
# quotient: 0.75
