# %%
## basic syntax rules in python
## case sensitivity-python is case sensitive

name="sandhya"
Name="mandlik"

print(name)
print(Name)
# Out:
# sandhya
# mandlik

# %%
## Indentation
## Pyhton uses indentation to define the blocks of code.

age=32
if age>30:
  print(age)

print(age)
# Out:
# 32
# 32

# %%
## this is single line comment

print("hello world")
# Out:
# hello world

# %%
## line continuation
## use a backslash (\) to continue a statement to the next line


total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## mutiple statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##understanding semantics in python
## variable assignment
age=32 ##age is an integer
name="sandhya"##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type interference
variable=10
print(type(variable))
variable="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
